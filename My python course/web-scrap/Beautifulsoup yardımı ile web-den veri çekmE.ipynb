# %%
#Beautifulsoup yardımı ile web-den veri çekme işlemi
import requests
from bs4 import BeautifulSoup
import wikipedia
import urllib3
header={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}
url="https://tr.wikipedia.org/wiki/Anasayfa"
get=requests.get(url,headers=header)
content=get.content
soup=BeautifulSoup(content,"html.parser")
titles=soup.find_all("div",{"class":"mw-parser-output"})
for i in titles:
    i = i.text
    print(i)
print(get.status_code)
# Out:
# Vikipedi'ye hoş geldiniz!
# Herkesin katkıda bulunabildiği özgür ansiklopedi
#
#
#
# Türkçe Vikipedi'deki madde sayısı: 534.135
#
# Madde oluştur
# Danış
# Nasıl?
# Cesur ol!
#
#
#
#
#
#
#
#
#
# Haftanın seçkin maddesi
#
#
# ...

# %%
#Beautifulsoup yardımı ile web-den veri çekme işlemi
import requests
from bs4 import BeautifulSoup
import wikipedia
import urllib3
header={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}
url="https://dbpedia.org/page/Ephesus"
get=requests.get(url,headers=header)
content=get.content
soup=BeautifulSoup(content,"html.parser")
titles=soup.find_all("div",{"class":"mw-parser-output"})
for i in titles:
    i = i.text
    print(i)
print(get.status_code)
# Out:
# 200
